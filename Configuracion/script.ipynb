-- %% [markdown]
-- # [PizzaT]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PizzaT]    Script Date: 13/11/2022 11:47:56 p. m. ******/
CREATE DATABASE [PizzaT]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PizzaDominos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\PizzaDominos.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PizzaDominos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\PizzaDominos_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [PizzaT] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PizzaT].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PizzaT] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PizzaT] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PizzaT] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PizzaT] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PizzaT] SET ARITHABORT OFF 
GO
ALTER DATABASE [PizzaT] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [PizzaT] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PizzaT] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PizzaT] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PizzaT] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PizzaT] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PizzaT] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PizzaT] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PizzaT] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PizzaT] SET  DISABLE_BROKER 
GO
ALTER DATABASE [PizzaT] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PizzaT] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PizzaT] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PizzaT] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PizzaT] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PizzaT] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PizzaT] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PizzaT] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [PizzaT] SET  MULTI_USER 
GO
ALTER DATABASE [PizzaT] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PizzaT] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PizzaT] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PizzaT] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PizzaT] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PizzaT] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [PizzaT] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [tyssen]

-- %%
USE [PizzaT]
GO

-- %%
/****** Object:  User [tyssen]    Script Date: 13/11/2022 11:47:56 p. m. ******/
CREATE USER [tyssen] FOR LOGIN [tyssen] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[Boxes]

-- %%
/****** Object:  Table [dbo].[Boxes]    Script Date: 13/11/2022 11:47:56 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Boxes](
	[id] [int] NOT NULL,
	[No_Caja] [int] NULL,
	[Vendedor] [varchar](50) NULL,
	[FechaHora] [datetime] NULL,
	[Ingreso] [decimal](18, 0) NULL,
	[Egreso] [decimal](18, 0) NULL,
	[V_Inicial_Caja] [decimal](18, 0) NULL,
	[V_Final_Caja] [decimal](18, 0) NULL,
	[Total_Ventas] [decimal](18, 0) NULL,
 CONSTRAINT [PK_Boxes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cliente]

-- %%
/****** Object:  Table [dbo].[Cliente]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Apellidos] [varchar](50) NULL,
	[Direccion] [nchar](10) NULL,
	[Telefono] [varchar](50) NULL,
 CONSTRAINT [PK_Cliente] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DETALLA_P]

-- %%
/****** Object:  Table [dbo].[DETALLA_P]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DETALLA_P](
	[ID] [int] NOT NULL,
	[id_cliente] [int] NULL,
	[id_vededor] [int] NULL,
	[id_TipoPizza] [int] NULL,
	[FechaPedido] [datetime] NULL,
	[CantidadPizza] [int] NULL,
	[fecha_Hora] [datetime] NULL,
	[MontoTotal] [decimal](18, 2) NULL,
	[cantidadPago] [decimal](18, 2) NULL,
	[cambio] [decimal](18, 2) NULL,
	[id_FormaPago] [int] NULL,
 CONSTRAINT [PK_DETALLA_P] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetallePedido]

-- %%
/****** Object:  Table [dbo].[DetallePedido]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetallePedido](
	[Cantidad] [int] NULL,
	[Total] [decimal](18, 0) NULL,
	[Pizza] [int] NULL,
	[id] [int] NOT NULL,
 CONSTRAINT [PK_DetallePedido] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FormaPago]

-- %%
/****** Object:  Table [dbo].[FormaPago]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FormaPago](
	[id] [int] NOT NULL,
	[Efectivo] [varchar](50) NULL,
	[Tarjeta] [varchar](50) NULL,
 CONSTRAINT [PK_FormaPago] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[P_Ingredientes]

-- %%
/****** Object:  Table [dbo].[P_Ingredientes]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[P_Ingredientes](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Ingredientes] [varchar](50) NULL,
 CONSTRAINT [PK_Ingredientes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[P_Tamaño]

-- %%
/****** Object:  Table [dbo].[P_Tamaño]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[P_Tamaño](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Tamaño] [int] NOT NULL,
 CONSTRAINT [PK_TamañoPizza] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[P_tipoMasa]

-- %%
/****** Object:  Table [dbo].[P_tipoMasa]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[P_tipoMasa](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Descripcon] [varchar](50) NULL,
 CONSTRAINT [PK_TipoPiza] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PizzaPersonaliza]

-- %%
/****** Object:  Table [dbo].[PizzaPersonaliza]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PizzaPersonaliza](
	[id] [int] NOT NULL,
	[Presio] [decimal](18, 0) NULL,
	[ID_tipoMasa] [int] NULL,
	[ID_igredientes] [int] NULL,
	[ID_Tamaño] [int] NULL,
 CONSTRAINT [PK_PizzaPersonaliza] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PizzaTradicional]

-- %%
/****** Object:  Table [dbo].[PizzaTradicional]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PizzaTradicional](
	[id] [int] NOT NULL,
	[ID_TipoPizzza] [int] NULL,
	[ID_Tamaño] [int] NULL,
 CONSTRAINT [PK_PizzaTradicional] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[T_Tamaño]

-- %%
/****** Object:  Table [dbo].[T_Tamaño]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[T_Tamaño](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[tamaño] [int] NULL,
	[Presio] [decimal](18, 2) NULL,
 CONSTRAINT [PK_T_Tamaño] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[T_tipoPiza]

-- %%
/****** Object:  Table [dbo].[T_tipoPiza]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[T_tipoPiza](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_T_tipoPiza] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ticket]

-- %%
/****** Object:  Table [dbo].[Ticket]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ticket](
	[id] [int] NOT NULL,
	[Fecha_Hora] [datetime] NULL,
	[MontoTotal] [decimal](18, 2) NULL,
	[idFormaPago] [int] NULL,
	[id_Detalle_P] [int] NULL,
	[CantidadPago] [decimal](18, 2) NULL,
	[Cambio] [decimal](18, 2) NULL,
 CONSTRAINT [PK_boleta] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TiposPizza]

-- %%
/****** Object:  Table [dbo].[TiposPizza]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TiposPizza](
	[Tradicional] [varchar](50) NULL,
	[Personalizada] [varchar](50) NULL,
	[id] [int] NOT NULL,
	[id_OpcionPizza] [int] NULL,
 CONSTRAINT [PK_TiposPizza] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vendedor]

-- %%
/****** Object:  Table [dbo].[Vendedor]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vendedor](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Apellido] [varchar](50) NULL,
	[Telefono] [varchar](50) NULL,
	[Edad] [int] NULL,
	[caja] [int] NULL,
 CONSTRAINT [PK_Vendedor] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vendedores]

-- %%
/****** Object:  Table [dbo].[Vendedores]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vendedores](
	[id] [int] NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Telefono] [varchar](50) NULL,
	[Edad] [int] NULL,
	[Direccion] [varchar](50) NOT NULL,
	[id_Boxes] [int] NULL,
 CONSTRAINT [PK_Vendedores] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_DETALLA_P_Cliente]

-- %%
ALTER TABLE [dbo].[DETALLA_P]  WITH CHECK ADD  CONSTRAINT [FK_DETALLA_P_Cliente] FOREIGN KEY([id_cliente])
REFERENCES [dbo].[Cliente] ([id])
GO
ALTER TABLE [dbo].[DETALLA_P] CHECK CONSTRAINT [FK_DETALLA_P_Cliente]
GO

-- %% [markdown]
-- # [FK_DETALLA_P_FormaPago]

-- %%
ALTER TABLE [dbo].[DETALLA_P]  WITH CHECK ADD  CONSTRAINT [FK_DETALLA_P_FormaPago] FOREIGN KEY([id_FormaPago])
REFERENCES [dbo].[FormaPago] ([id])
GO
ALTER TABLE [dbo].[DETALLA_P] CHECK CONSTRAINT [FK_DETALLA_P_FormaPago]
GO

-- %% [markdown]
-- # [FK_DETALLA_P_TiposPizza]

-- %%
ALTER TABLE [dbo].[DETALLA_P]  WITH CHECK ADD  CONSTRAINT [FK_DETALLA_P_TiposPizza] FOREIGN KEY([id_TipoPizza])
REFERENCES [dbo].[TiposPizza] ([id])
GO
ALTER TABLE [dbo].[DETALLA_P] CHECK CONSTRAINT [FK_DETALLA_P_TiposPizza]
GO

-- %% [markdown]
-- # [FK_DETALLA_P_Vendedor]

-- %%
ALTER TABLE [dbo].[DETALLA_P]  WITH CHECK ADD  CONSTRAINT [FK_DETALLA_P_Vendedor] FOREIGN KEY([id_vededor])
REFERENCES [dbo].[Vendedor] ([id])
GO
ALTER TABLE [dbo].[DETALLA_P] CHECK CONSTRAINT [FK_DETALLA_P_Vendedor]
GO

-- %% [markdown]
-- # [FK_PizzaPersonaliza_P_Ingredientes]

-- %%
ALTER TABLE [dbo].[PizzaPersonaliza]  WITH CHECK ADD  CONSTRAINT [FK_PizzaPersonaliza_P_Ingredientes] FOREIGN KEY([ID_igredientes])
REFERENCES [dbo].[P_Ingredientes] ([id])
GO
ALTER TABLE [dbo].[PizzaPersonaliza] CHECK CONSTRAINT [FK_PizzaPersonaliza_P_Ingredientes]
GO

-- %% [markdown]
-- # [FK_PizzaPersonaliza_P_Tamaño]

-- %%
ALTER TABLE [dbo].[PizzaPersonaliza]  WITH CHECK ADD  CONSTRAINT [FK_PizzaPersonaliza_P_Tamaño] FOREIGN KEY([ID_Tamaño])
REFERENCES [dbo].[P_Tamaño] ([id])
GO
ALTER TABLE [dbo].[PizzaPersonaliza] CHECK CONSTRAINT [FK_PizzaPersonaliza_P_Tamaño]
GO

-- %% [markdown]
-- # [FK_PizzaPersonaliza_P_tipoMasa]

-- %%
ALTER TABLE [dbo].[PizzaPersonaliza]  WITH CHECK ADD  CONSTRAINT [FK_PizzaPersonaliza_P_tipoMasa] FOREIGN KEY([ID_tipoMasa])
REFERENCES [dbo].[P_tipoMasa] ([id])
GO
ALTER TABLE [dbo].[PizzaPersonaliza] CHECK CONSTRAINT [FK_PizzaPersonaliza_P_tipoMasa]
GO

-- %% [markdown]
-- # [FK_PizzaTradicional_T_Tamaño]

-- %%
ALTER TABLE [dbo].[PizzaTradicional]  WITH CHECK ADD  CONSTRAINT [FK_PizzaTradicional_T_Tamaño] FOREIGN KEY([ID_Tamaño])
REFERENCES [dbo].[T_Tamaño] ([id])
GO
ALTER TABLE [dbo].[PizzaTradicional] CHECK CONSTRAINT [FK_PizzaTradicional_T_Tamaño]
GO

-- %% [markdown]
-- # [FK_PizzaTradicional_T_tipoPiza]

-- %%
ALTER TABLE [dbo].[PizzaTradicional]  WITH CHECK ADD  CONSTRAINT [FK_PizzaTradicional_T_tipoPiza] FOREIGN KEY([ID_TipoPizzza])
REFERENCES [dbo].[T_tipoPiza] ([id])
GO
ALTER TABLE [dbo].[PizzaTradicional] CHECK CONSTRAINT [FK_PizzaTradicional_T_tipoPiza]
GO

-- %% [markdown]
-- # [FK_TiposPizza_PizzaPersonaliza1]

-- %%
ALTER TABLE [dbo].[TiposPizza]  WITH CHECK ADD  CONSTRAINT [FK_TiposPizza_PizzaPersonaliza1] FOREIGN KEY([id_OpcionPizza])
REFERENCES [dbo].[PizzaPersonaliza] ([id])
GO
ALTER TABLE [dbo].[TiposPizza] CHECK CONSTRAINT [FK_TiposPizza_PizzaPersonaliza1]
GO

-- %% [markdown]
-- # [FK_TiposPizza_PizzaTradicional1]

-- %%
ALTER TABLE [dbo].[TiposPizza]  WITH CHECK ADD  CONSTRAINT [FK_TiposPizza_PizzaTradicional1] FOREIGN KEY([id_OpcionPizza])
REFERENCES [dbo].[PizzaTradicional] ([id])
GO
ALTER TABLE [dbo].[TiposPizza] CHECK CONSTRAINT [FK_TiposPizza_PizzaTradicional1]
GO

-- %% [markdown]
-- # [FK_Vendedores_Boxes]

-- %%
ALTER TABLE [dbo].[Vendedores]  WITH CHECK ADD  CONSTRAINT [FK_Vendedores_Boxes] FOREIGN KEY([id_Boxes])
REFERENCES [dbo].[Boxes] ([id])
GO
ALTER TABLE [dbo].[Vendedores] CHECK CONSTRAINT [FK_Vendedores_Boxes]
GO

-- %% [markdown]
-- # [dbo].[CRUD_CLIENTE]

-- %%
/****** Object:  StoredProcedure [dbo].[CRUD_CLIENTE]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CRUD_CLIENTE]

@busqueda varchar(50) = '', 
@id int = 0,
@Nombre varchar (50) = '',
@Apellidos varchar(50) = '', 
@direccion varchar(50) = '',
@telefono varchar(50) = '', 

@opcion char (1)

as 
   IF @opcion = 'I'
  
    --if exists (select * from Cliente where id = @id)
	--begin 
		--print'Cliente ya Existente'
	   -- return 
	--end 

   
	begin 


	    INSERT INTO Cliente (id, Nombre, Apellidos, Direccion, Telefono)
						values(@id, @Nombre, @Apellidos, @direccion, @telefono); 


						--declare @idCliente as int = (select max (id) from Cliente)

					
						--insert into PEDIDOUNO(ID_Cliente)
						--values (@idCliente)

	end 


	begin 

	select * from Cliente where id = @id
	end 


	IF @opcion = 'U'
	begin 
	     update Cliente set id = @id,
		                    Nombre = @Nombre,
							Apellidos = @Apellidos,
							Direccion = @direccion, 
							Telefono = @telefono
		WHERE id = @id or Nombre = @Nombre 


	end 


	IF @opcion = 'D' 
	BEGIN 
	      DELETE FROM Cliente
		  WHERE id = @id 
          

		  --delete FROM Pedido--
		  --where id = @id--

	end


	IF @opcion = 'M'
	BEGIN 
	     SELECT id,
		 Nombre,
		 Telefono,
		 Apellidos,
		 Direccion,
		 Telefono
		 
		 
		 
		 FROM Cliente where id like '%' + @busqueda + '%' or Nombre like '%' + @busqueda + '%' or Apellidos like '%' + @busqueda + '%'
	end 
GO

-- %% [markdown]
-- # [dbo].[CRUD_VENDEDOR]

-- %%
/****** Object:  StoredProcedure [dbo].[CRUD_VENDEDOR]    Script Date: 13/11/2022 11:47:57 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[CRUD_VENDEDOR]

@busqueda varchar (50) = '',
@id int = 0, 
@Nombre varchar (50) = '', 
@Apellido varchar (50) = '',
@Telefono varchar (50) = '',
@Edad int = 0,
@Caja int = 0, 
@opcion char (1)


as 
   IF @opcion = 'I'
   begin 
        INSERT INTO Vendedor (id, Nombre, Apellido, telefono, edad, caja)
		                values(@id, @Nombre, @Apellido, @Telefono, @Edad,@Caja);

						declare @idVendedor as int = (select max (id) from Vendedor)

						insert into Pedido (idVendedor)
						values (@idVendedor)




   end 

   IF @opcion  = 'U'
   BEGIN 
         UPDATE Vendedor set id =@id,
		                     Nombre = @Nombre,
							 Apellido = @Apellido,
							 telefono = @Telefono, 
							 Edad = @Edad,
							 caja = @caja
		 where id = @id OR Nombre = @Nombre

	END 


	IF @opcion = 'D'
	BEGIN 
	     DELETE FROM Vendedor

		 WHERE id = @id or Nombre = @Nombre


		 DELETE FROM Pedido

		 WHERE id = @id

	end 

	IF @opcion = 'M'

	BEGIN 
	     SELECT id,
		        Nombre,
				Apellido,
				Telefono,
				edad, 
				caja
		 FROM Vendedor 
		 WHERE id like '%' + @busqueda + '%' or Nombre like '%' + @busqueda + '%' or Apellido like '%' +@busqueda + '%'

	end 
GO

-- %% [markdown]
-- # [PizzaT]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PizzaT] SET  READ_WRITE 
GO
